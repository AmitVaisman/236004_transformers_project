# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('metrics.csv')
df['train/expression_loss']
# Out:
# 0      9.101562
# 1      8.234375
# 2      6.695312
# 3      8.164062
# 4      4.753906
#          ...
# 195    0.036011
# 196    0.035400
# 197    0.066956
# 198    0.018814
# 199    0.064697
# Name: train/expression_loss, Length: 200, dtype: float64

# %%
sns.lineplot(df, x='step', y='train/expression_loss')
sns.lineplot(df, x='step', y='train/lambda_reg_log')
plt.grid()
plt.show()
